# %% [markdown]
# # Rate my Professor Project
# This is Part 2 of a comprehensive RateMyProfessor project aimed at building an overview of faculty and professor ratings at Cal Poly Pomona. The goal is to provide students with accessible and aggregated insights into how professors are rated on the RateMyProfessor platform.
#
# In this phase of the project, we focus on basic data cleaning of the in-depth ratings, student comments, and specific course information contained within our CSV dataset. The goal is to prepare the data for more advanced analysis by ensuring consistency, accuracy, and completeness across key fields.
#
# Once the initial cleaning is complete, we plan to transition to using SQL for deeper analysis, including joining this dataset with Part 1 of the project to enable richer, more integrated insights
#
# The data was collected using a custom web scraping bot built with Selenium, designed to extract information on both current and former professors at Cal Poly Pomona.
#
# The dataset below was scraped from RateMyProfessor and contains information on faculty from Cal Poly Pomona. Each row represents a professor, along with their aggregated rating and departmental data.
#
# Columns Explained:
#
# ```Professor_ID:``` A unique identifier assigned to each professor.
#
# ```Professor_Name:``` The full name of the professor.
#
# ```University:``` The academic department the professor belongs to. However, we would like to change to the academic college the professor belongs to.
#
# ```Department:``` The academic department the professor belongs to.
#
# ```Quality:``` Overall quality rating given by students, scale from 1-5
#
# ```Difficulty:``` Perceived difficulty of the professor's class, scale from 1-5
#
# ```Class_Name:``` Name or code of the course being reviewed
#
# ```Comment:``` Written review or remarks left by students with their experience with the professor and course
#
# ```Thumbs_Up:``` The number of users who found the comment helpful or agreed with the review (indicating satisfaction).
#
# ```Thumbs_Down:``` The number of users who disagreed or found the review unhelpful (indicating dissatisfaction).
#
# ```Review_Date:``` The date the review was submitted.

# %%
# Importing necessary libraries
import pandas as pd

# %%
# Read CSV without initial data cleaning/parsing
df = pd.read_csv(r'C:\Users\Ivan\Downloads\Ratemyprofesser_dataclean\ratemyprofessors_reviews.csv')
df
# Out:
#        Professor_ID   Professor_Name                University  \
# 0           1277216        Nancy Fan     Accounting department
# 1           1277216        Nancy Fan     Accounting department
# 2           1277216        Nancy Fan     Accounting department
# 3           1277216        Nancy Fan     Accounting department
# 4           1277216        Nancy Fan     Accounting department
# ...             ...              ...                       ...
# 34641        958068  Rhodes Rhonda L  Not Specified department
# 34642        959066       Angie Song  Not Specified department
# 34643        959066       Angie Song  Not Specified department
# 34644        959066       Angie Song  Not Specified department
# 34645        959066       Angie Song  Not Specified department
#
#                      Department  Quality  Difficulty Class_Name  \
# 0         Accounting department      1.0         5.0    ACC3120
# 1         Accounting department      1.0         3.0    ACC3120
# 2         Accounting department      1.0         4.0    ACC3120
# 3         Accounting department      1.0         4.0    ACC3110
# 4         Accounting department      2.0         4.0    ACC3120
# ...                         ...      ...         ...        ...
# 34641  Not Specified department      4.0         2.0     TOM411
# 34642  Not Specified department      4.5         2.0      LA251
# 34643  Not Specified department      5.0         2.0    CADSECT
# 34644  Not Specified department      5.0         2.0    CADSECT
# 34645  Not Specified department      4.5         2.0      LA252
#
#                                                  Comment  Thumbs_Up  \
# 0      Nancy Fan holds the keys to your future. Cal P...        0.0
# 1      She jumps over read the textbook. Shows you th...        0.0
# 2      Unfortunately, she's the only one teaching ACC...        1.0
# 3                   PLEASE DO NOT TAKE HER!!!!!!!!!!!!!!        0.0
# 4      Her homework is done through McGraw Hill. Alth...        0.0
# ...                                                  ...        ...
# 34641  Class is easy. The only hard part would probab...        0.0
# 34642  She is very helpful, very clear in her critics...        0.0
# 34643                                        No Comments        0.0
# 34644                                        No Comments        0.0
# 34645  Very helpful teacher no matter how little you ...        0.0
#
#        Thumbs_Down     Review_Date
# 0              0.0  Mar 19th, 2025
# 1              0.0  Mar 13th, 2025
# 2              0.0  Feb 11th, 2025
# 3              0.0   Feb 6th, 2025
# 4              0.0   Feb 5th, 2025
# ...            ...             ...
# 34641          0.0   Aug 6th, 2009
# 34642          0.0  Dec 17th, 2009
# 34643          0.0  Jul 31st, 2007
# 34644          0.0  Jul 31st, 2007
# 34645          0.0  Feb 16th, 2007
#
# [34646 rows x 11 columns]

# %% [markdown]
# # Data Cleaning
#
# This Section will focus on ensuring consistency, handling missing values, and standardizing format

# %%
# Print information regarding the df's index, dtype, non/null values, memory usuage, and column information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34646 entries, 0 to 34645
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Professor_ID    34646 non-null  int64
#  1   Professor_Name  34646 non-null  object
#  2   University      34646 non-null  object
#  3   Department      34646 non-null  object
#  4   Quality         34620 non-null  float64
#  5   Difficulty      34621 non-null  float64
#  6   Class_Name      34619 non-null  object
#  7   Comment         34616 non-null  object
#  8   Thumbs_Up       34620 non-null  float64
#  9   Thumbs_Down     34620 non-null  float64
#  10  Review_Date     34618 non-null  object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 2.9+ MB

# %%
# Dropping any duplicates 
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#        Professor_ID   Professor_Name                University  \
# 0           1277216        Nancy Fan     Accounting department
# 1           1277216        Nancy Fan     Accounting department
# 2           1277216        Nancy Fan     Accounting department
# 3           1277216        Nancy Fan     Accounting department
# 4           1277216        Nancy Fan     Accounting department
# ...             ...              ...                       ...
# 34640        958068  Rhodes Rhonda L  Not Specified department
# 34641        958068  Rhodes Rhonda L  Not Specified department
# 34642        959066       Angie Song  Not Specified department
# 34643        959066       Angie Song  Not Specified department
# 34645        959066       Angie Song  Not Specified department
#
#                      Department  Quality  Difficulty Class_Name  \
# 0         Accounting department      1.0         5.0    ACC3120
# 1         Accounting department      1.0         3.0    ACC3120
# 2         Accounting department      1.0         4.0    ACC3120
# 3         Accounting department      1.0         4.0    ACC3110
# 4         Accounting department      2.0         4.0    ACC3120
# ...                         ...      ...         ...        ...
# 34640  Not Specified department      4.0         3.0     EBZ466
# 34641  Not Specified department      4.0         2.0     TOM411
# 34642  Not Specified department      4.5         2.0      LA251
# 34643  Not Specified department      5.0         2.0    CADSECT
# 34645  Not Specified department      4.5         2.0      LA252
#
#                                                  Comment  Thumbs_Up  \
# 0      Nancy Fan holds the keys to your future. Cal P...        0.0
# 1      She jumps over read the textbook. Shows you th...        0.0
# 2      Unfortunately, she's the only one teaching ACC...        1.0
# 3                   PLEASE DO NOT TAKE HER!!!!!!!!!!!!!!        0.0
# 4      Her homework is done through McGraw Hill. Alth...        0.0
# ...                                                  ...        ...
# 34640  You get a choice to do either an internship or...        0.0
# 34641  Class is easy. The only hard part would probab...        0.0
# 34642  She is very helpful, very clear in her critics...        0.0
# 34643                                        No Comments        0.0
# 34645  Very helpful teacher no matter how little you ...        0.0
#
#        Thumbs_Down     Review_Date
# 0              0.0  Mar 19th, 2025
# 1              0.0  Mar 13th, 2025
# 2              0.0  Feb 11th, 2025
# 3              0.0   Feb 6th, 2025
# 4              0.0   Feb 5th, 2025
# ...            ...             ...
# 34640          0.0  Dec 16th, 2009
# 34641          0.0   Aug 6th, 2009
# 34642          0.0  Dec 17th, 2009
# 34643          0.0  Jul 31st, 2007
# 34645          0.0  Feb 16th, 2007
#
# [34613 rows x 11 columns]

# %%
# Checking for any NaN/Nulls
df.isna().any()
# Out:
# Professor_ID      False
# Professor_Name    False
# University        False
# Department        False
# Quality            True
# Difficulty         True
# Class_Name         True
# Comment            True
# Thumbs_Up          True
# Thumbs_Down        True
# Review_Date        True
# dtype: bool

# %%
# Replacing NaN with "No Comments" 
df["Comment"] = df["Comment"].fillna("No Comments")

# %%
# Dropping NaN Courses
df.dropna(subset=['Class_Name'], inplace=True)

# %%
# Checking Total # of NaN/Null
df.isna().sum()
# Out:
# Professor_ID      0
# Professor_Name    0
# University        0
# Department        0
# Quality           0
# Difficulty        0
# Class_Name        0
# Comment           0
# Thumbs_Up         0
# Thumbs_Down       0
# Review_Date       1
# dtype: int64

# %%
# Dropping NaN Date
df.dropna(subset=['Review_Date'], inplace=True)

# %%
# Double checking
df.isna().sum()
# Out:
# Professor_ID      0
# Professor_Name    0
# University        0
# Department        0
# Quality           0
# Difficulty        0
# Class_Name        0
# Comment           0
# Thumbs_Up         0
# Thumbs_Down       0
# Review_Date       0
# dtype: int64

# %%
# Checking the information again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34607 entries, 0 to 34645
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Professor_ID    34607 non-null  int64
#  1   Professor_Name  34607 non-null  object
#  2   University      34607 non-null  object
#  3   Department      34607 non-null  object
#  4   Quality         34607 non-null  float64
#  5   Difficulty      34607 non-null  float64
#  6   Class_Name      34607 non-null  object
#  7   Comment         34607 non-null  object
#  8   Thumbs_Up       34607 non-null  float64
#  9   Thumbs_Down     34607 non-null  float64
#  10  Review_Date     34607 non-null  object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 3.2+ MB

# %% [markdown]
# Quality, Difficulty, Thumbs_Up/Downs dtype should be considered int32.

# %%
# Converting dtype to int
df['Thumbs_Down'] = df['Thumbs_Down'].astype(int)
df['Thumbs_Up'] = df['Thumbs_Up'].astype(int)
df['Quality'] = df['Quality'].astype(int)
df['Difficulty'] = df['Difficulty'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34607 entries, 0 to 34645
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Professor_ID    34607 non-null  int64
#  1   Professor_Name  34607 non-null  object
#  2   University      34607 non-null  object
#  3   Department      34607 non-null  object
#  4   Quality         34607 non-null  int32
#  5   Difficulty      34607 non-null  int32
#  6   Class_Name      34607 non-null  object
#  7   Comment         34607 non-null  object
#  8   Thumbs_Up       34607 non-null  int32
#  9   Thumbs_Down     34607 non-null  int32
#  10  Review_Date     34607 non-null  object
# dtypes: int32(4), int64(1), object(6)
# memory usage: 2.6+ MB

# %%
df
# Out:
#        Professor_ID   Professor_Name                University  \
# 0           1277216        Nancy Fan     Accounting department
# 1           1277216        Nancy Fan     Accounting department
# 2           1277216        Nancy Fan     Accounting department
# 3           1277216        Nancy Fan     Accounting department
# 4           1277216        Nancy Fan     Accounting department
# ...             ...              ...                       ...
# 34640        958068  Rhodes Rhonda L  Not Specified department
# 34641        958068  Rhodes Rhonda L  Not Specified department
# 34642        959066       Angie Song  Not Specified department
# 34643        959066       Angie Song  Not Specified department
# 34645        959066       Angie Song  Not Specified department
#
#                      Department  Quality  Difficulty Class_Name  \
# 0         Accounting department        1           5    ACC3120
# 1         Accounting department        1           3    ACC3120
# 2         Accounting department        1           4    ACC3120
# 3         Accounting department        1           4    ACC3110
# 4         Accounting department        2           4    ACC3120
# ...                         ...      ...         ...        ...
# 34640  Not Specified department        4           3     EBZ466
# 34641  Not Specified department        4           2     TOM411
# 34642  Not Specified department        4           2      LA251
# 34643  Not Specified department        5           2    CADSECT
# 34645  Not Specified department        4           2      LA252
#
#                                                  Comment  Thumbs_Up  \
# 0      Nancy Fan holds the keys to your future. Cal P...          0
# 1      She jumps over read the textbook. Shows you th...          0
# 2      Unfortunately, she's the only one teaching ACC...          1
# 3                   PLEASE DO NOT TAKE HER!!!!!!!!!!!!!!          0
# 4      Her homework is done through McGraw Hill. Alth...          0
# ...                                                  ...        ...
# 34640  You get a choice to do either an internship or...          0
# 34641  Class is easy. The only hard part would probab...          0
# 34642  She is very helpful, very clear in her critics...          0
# 34643                                        No Comments          0
# 34645  Very helpful teacher no matter how little you ...          0
#
#        Thumbs_Down     Review_Date
# 0                0  Mar 19th, 2025
# 1                0  Mar 13th, 2025
# 2                0  Feb 11th, 2025
# 3                0   Feb 6th, 2025
# 4                0   Feb 5th, 2025
# ...            ...             ...
# 34640            0  Dec 16th, 2009
# 34641            0   Aug 6th, 2009
# 34642            0  Dec 17th, 2009
# 34643            0  Jul 31st, 2007
# 34645            0  Feb 16th, 2007
#
# [34607 rows x 11 columns]

# %% [markdown]
# # Handling Missing Values & Validate Column Ranges
#
# Identify and address missing or incorrect formatting within the data frame along with ensuring columns constriants
#
# ## Given the knowledge on  the columns:
# ```Professor_ID:``` Should be unique or at least consistent in format.
#
# ```Professor_Name:``` Should be consistently formatted (e.g., First Last), with no extra spaces or all-caps issues.
#
# ```University:``` Must be between 0 and 5.
#
# ```Quality:``` Must be between 0 and 5 and cannot contain negatives
#
# ```Difficulty:``` Must be between 0 and 5 and cannot contain negatives
#
# ```Class_Name:``` contain class name
#
# ```Comment:``` Contains no NaN or at least No Comment
#
# ```Thumbs_Up/Down:``` Cannot contain negatives
#
# ```Review_Date:``` Showcase accurate date in a proper format

# %%
df['Professor_ID'].unique()
# Out:
# array([1277216, 2238743, 2306997, ...,  744993,  958068,  959066],
#       dtype=int64)

# %%
# Doubling to make sure no negative are present 
df[df['Professor_ID'] < 0]['Professor_ID'].unique()
# Out:
# array([], dtype=int64)

# %% [markdown]
# Since we already standardized the Professors's names in Part 1, we will be reusing the same code from the previous Pandas Worksheets. With some adjustments

# %%
df.loc[df['Professor_Name'] == 'Dr. Thomas Keith', 'Professor_Name'] = 'Thomas Keith'

# %%
df.loc[df['Professor_Name'] == 'Dr. J Phillips', 'Professor_Name'] = 'J Phillips'

# %%
df.loc[df['Professor_Name'] == 'David  Dennis III', 'Professor_Name'] = 'David Dennis'

# %%
df.loc[df['Professor_Name'] == 'Rhodes Rhonda L', 'Professor_Name'] = 'Rhodes Rhonda'

# %%
df.loc[df['Professor_Name'] == '(Bernardus) Ben Dewald', 'Professor_Name'] = 'Ben Dewald'

# %%
df.loc[df['Professor_Name'] == 'O. David Mylander', 'Professor_Name'] = 'David Mylander'

# %%
df.loc[df['Professor_Name'] == 'Leonard K Vandegrift Iv', 'Professor_Name'] = 'Leonard Vandegrift'

# %%
# let create an object that removes the expression and middle names 
def clean_professor_name(name):
    name = str(name)
    
    # Remove anything in parentheses (e.g., nicknames)
    while '(' in name and ')' in name:
        start = name.find('(')
        end = name.find(')', start)
        name = name[:start] + name[end+1:]

    # Remove double quotes and single quotes
    for symbol in ['"', "'", '`']:
        name = name.replace(symbol, '')

    # Remove commas, periods, slashes, and dashes
    for char in [',', '.', '/']:
        name = name.replace(char, '')

    # Remove extra whitespace
    name = ' '.join(name.split())

    # Keep only first and last name if more than two words
    parts = name.split()
    if len(parts) > 2:
        name = parts[0] + ' ' + parts[-1]

    return name

# Apply to the column
df['Professor_Name'] = df['Professor_Name'].apply(clean_professor_name)

# %% [markdown]
# Let's move onto Departments/Unversity Columns

# %%
df["Department"].unique()
# Out:
# array(['Accounting department', 'Agriculture department',
#        'Animal Science department', 'Anthropology department',
#        'Anthropology & Geo Sciences department',
#        'Apparel Merchandising department', 'Architecture department',
#        'Art History department', 'Biology department',
#        'Business department', 'Chemistry department',
#        'Civil Engineering department', 'Communication department',
#        'Computer Information Systems department',
#        'Computer Science department', 'Criminal Justice department',
#        'Culinary Arts department', 'Dance department',
#        'Design department', 'Economics department',
#        'Education department',
#        'Electrical Engineering & Computer Science department',
#        'Engineering department',
#        'Engineering & Computer Science department', 'English department',
#        'English & Languages department', 'Ethnic Studies department',
#        'Film department', 'Finance department', 'Fine Arts department',
#        'Foods & Nutrition department', 'Geography department',
#        'Geology department', 'Graphic Arts department',
#        'Health Science department', 'History department',
#        'Horticulture department', 'Hospitality department',
#        'Humanities department', 'Information Science department',
#        'Interdisciplinary General Ed. department',
#        'International Bus. & Marketing department',
#        'Journalism department', 'Kinesiology department',
#        'Landscape Architecture department',
#        'Landscape Architecture & Regional Planning department',
#        'Languages department', 'Law department',
#        'Liberal Studies department', 'Literature department',
#        'Management department', 'Marketing department',
#        'Mathematics department', 'Mechanical Engineering department',
#        'Medicine department', 'Music department', 'Philosophy department',
#        'Physical Education department', 'Physics department',
#        'Political Science department', 'Psychology department',
#        'Religion department', 'Science department',
#        'Science/Engineering department', 'Social Science department',
#        'Social Work department', 'Sociology department',
#        'Technology & Operations Mgmt department', 'Theater department',
#        'Urban & Regional Planning department',
#        'Urban Design & Development department',
#        'Veterinary Sciences department', "Women's Studies department",
#        'ScienceEngineering department', 'Physical Ed department',
#        'Not Specified department'], dtype=object)

# %%
University_dict = {
    'English & Languages department': 'English department',
    'Science/Engineering department': 'Science department',
    'Information Science department': 'Computer Information Systems department',
    'Anthropology & Geo Sciences department': 'Anthropology department',
    'ScienceEngineering department': 'Science department',
    'Physical Education department': 'Physical Ed department',
    'International Bus. & Marketing department': 'International Business department',
    'Electrical Engineering & Computer Science department': 'Electrical Engineering department',
    'Engineering & Computer Science department': 'Computer Engineering department',
    'Landscape Architecture & Regional Planning department': 'Landscape Architecture department',
    'Technology & Operations Mgmt department': 'Technology Operations Mgmt department',
    'Urban & Regional Planning department': 'Urban Regional Planning department',
    'Urban Design & Development department': 'Urban Design department',
    'Interdisciplinary General Ed. department': 'General Ed department',
    "Women's Studies department": 'Gender Studies department',
    "Foods & Nutrition department": 'Nutrition department',

}

# %%
df['University'] = df['University'].replace(University_dict)
df["University"].unique()
# Out:
# array(['Accounting department', 'Agriculture department',
#        'Animal Science department', 'Anthropology department',
#        'Apparel Merchandising department', 'Architecture department',
#        'Art History department', 'Biology department',
#        'Business department', 'Chemistry department',
#        'Civil Engineering department', 'Communication department',
#        'Computer Information Systems department',
#        'Computer Science department', 'Criminal Justice department',
#        'Culinary Arts department', 'Dance department',
#        'Design department', 'Economics department',
#        'Education department', 'Electrical Engineering department',
#        'Engineering department', 'Computer Engineering department',
#        'English department', 'Ethnic Studies department',
#        'Film department', 'Finance department', 'Fine Arts department',
#        'Nutrition department', 'Geography department',
#        'Geology department', 'Graphic Arts department',
#        'Health Science department', 'History department',
#        'Horticulture department', 'Hospitality department',
#        'Humanities department', 'General Ed department',
#        'International Business department', 'Journalism department',
#        'Kinesiology department', 'Landscape Architecture department',
#        'Languages department', 'Law department',
#        'Liberal Studies department', 'Literature department',
#        'Management department', 'Marketing department',
#        'Mathematics department', 'Mechanical Engineering department',
#        'Medicine department', 'Music department', 'Philosophy department',
#        'Physical Ed department', 'Physics department',
#        'Political Science department', 'Psychology department',
#        'Religion department', 'Science department',
#        'Social Science department', 'Social Work department',
#        'Sociology department', 'Technology Operations Mgmt department',
#        'Theater department', 'Urban Regional Planning department',
#        'Urban Design department', 'Veterinary Sciences department',
#        'Gender Studies department', 'Not Specified department'],
#       dtype=object)

# %%
df['Department'] = df['Department'].replace(University_dict)

# %%
df["Department"].unique()
# Out:
# array(['Accounting department', 'Agriculture department',
#        'Animal Science department', 'Anthropology department',
#        'Apparel Merchandising department', 'Architecture department',
#        'Art History department', 'Biology department',
#        'Business department', 'Chemistry department',
#        'Civil Engineering department', 'Communication department',
#        'Computer Information Systems department',
#        'Computer Science department', 'Criminal Justice department',
#        'Culinary Arts department', 'Dance department',
#        'Design department', 'Economics department',
#        'Education department', 'Electrical Engineering department',
#        'Engineering department', 'Computer Engineering department',
#        'English department', 'Ethnic Studies department',
#        'Film department', 'Finance department', 'Fine Arts department',
#        'Nutrition department', 'Geography department',
#        'Geology department', 'Graphic Arts department',
#        'Health Science department', 'History department',
#        'Horticulture department', 'Hospitality department',
#        'Humanities department', 'General Ed department',
#        'International Business department', 'Journalism department',
#        'Kinesiology department', 'Landscape Architecture department',
#        'Languages department', 'Law department',
#        'Liberal Studies department', 'Literature department',
#        'Management department', 'Marketing department',
#        'Mathematics department', 'Mechanical Engineering department',
#        'Medicine department', 'Music department', 'Philosophy department',
#        'Physical Ed department', 'Physics department',
#        'Political Science department', 'Psychology department',
#        'Religion department', 'Science department',
#        'Social Science department', 'Social Work department',
#        'Sociology department', 'Technology Operations Mgmt department',
#        'Theater department', 'Urban Regional Planning department',
#        'Urban Design department', 'Veterinary Sciences department',
#        'Gender Studies department', 'Not Specified department'],
#       dtype=object)

# %%
college_mapping = {
    "College of Agriculture": ["Agriculture", "Animal Science", "Horticulture", "Nutrition", "Veterinary Sciences", "Apparel Merchandising"],
    "College of Business Administration": ["Accounting", "Business", "Finance", "Marketing", "Management", "International Business", "Technology Operations Mgmt", "Computer Information Systems", "Law"],
    "College of Education and Integrative Studies": ["General Ed","Education", "Liberal Studies", "Social Work"],
    "College of Engineering": ["Civil Engineering", "Electrical Engineering", "Mechanical Engineering", "Engineering", "Computer Engineering"],
    "College of Environmental Design": ["Architecture", "Landscape Architecture", "Urban Regional Planning", "Urban Design", "Apparel Merchandising", "Graphic Arts", "Design"],
    "College of Letters, Arts, and Social Sciences": ["Anthropology", "Communication", "Criminal Justice", "Dance", "Economics", "English", "Ethnic Studies", "Film", "Geography", "History", "Humanities", "Journalism", "Languages", "Literature", "Music", "Philosophy", "Political Science", "Psychology", "Religion", "Social Science", "Sociology", "Theater", "Gender Studies", "Fine Arts", "Art History"],
    "College of Science": ["Biology", "Chemistry", "Computer Science", "Kinesiology", "Physical Ed", "Geology", "Health Science", "Mathematics", "Medicine", "Physics", "Science"],
    "College of Hospitality Management": ["Hospitality", "Culinary Arts"],
    "Not Specified": ["Not Specified"]
}

# Function to assign a college
def assign_college(University):
    for college, keywords in college_mapping.items():
        for keyword in keywords:
            if keyword.lower() in University.lower():
                return college
    return "Unmatched"


df["University"] = df["University"].apply(assign_college)

# %%
df["University"].unique()
# Out:
# array(['College of Business Administration', 'College of Agriculture',
#        'College of Letters, Arts, and Social Sciences',
#        'College of Environmental Design', 'College of Science',
#        'College of Engineering', 'College of Hospitality Management',
#        'College of Education and Integrative Studies', 'Not Specified'],
#       dtype=object)

# %%
df
# Out:
#        Professor_ID Professor_Name                          University  \
# 0           1277216      Nancy Fan  College of Business Administration
# 1           1277216      Nancy Fan  College of Business Administration
# 2           1277216      Nancy Fan  College of Business Administration
# 3           1277216      Nancy Fan  College of Business Administration
# 4           1277216      Nancy Fan  College of Business Administration
# ...             ...            ...                                 ...
# 34640        958068  Rhodes Rhonda                       Not Specified
# 34641        958068  Rhodes Rhonda                       Not Specified
# 34642        959066     Angie Song                       Not Specified
# 34643        959066     Angie Song                       Not Specified
# 34645        959066     Angie Song                       Not Specified
#
#                      Department  Quality  Difficulty Class_Name  \
# 0         Accounting department        1           5    ACC3120
# 1         Accounting department        1           3    ACC3120
# 2         Accounting department        1           4    ACC3120
# 3         Accounting department        1           4    ACC3110
# 4         Accounting department        2           4    ACC3120
# ...                         ...      ...         ...        ...
# 34640  Not Specified department        4           3     EBZ466
# 34641  Not Specified department        4           2     TOM411
# 34642  Not Specified department        4           2      LA251
# 34643  Not Specified department        5           2    CADSECT
# 34645  Not Specified department        4           2      LA252
#
#                                                  Comment  Thumbs_Up  \
# 0      Nancy Fan holds the keys to your future. Cal P...          0
# 1      She jumps over read the textbook. Shows you th...          0
# 2      Unfortunately, she's the only one teaching ACC...          1
# 3                   PLEASE DO NOT TAKE HER!!!!!!!!!!!!!!          0
# 4      Her homework is done through McGraw Hill. Alth...          0
# ...                                                  ...        ...
# 34640  You get a choice to do either an internship or...          0
# 34641  Class is easy. The only hard part would probab...          0
# 34642  She is very helpful, very clear in her critics...          0
# 34643                                        No Comments          0
# 34645  Very helpful teacher no matter how little you ...          0
#
#        Thumbs_Down     Review_Date
# 0                0  Mar 19th, 2025
# 1                0  Mar 13th, 2025
# 2                0  Feb 11th, 2025
# 3                0   Feb 6th, 2025
# 4                0   Feb 5th, 2025
# ...            ...             ...
# 34640            0  Dec 16th, 2009
# 34641            0   Aug 6th, 2009
# 34642            0  Dec 17th, 2009
# 34643            0  Jul 31st, 2007
# 34645            0  Feb 16th, 2007
#
# [34607 rows x 11 columns]

# %%
df["University"].unique()
# Out:
# array(['College of Business Administration', 'College of Agriculture',
#        'College of Letters, Arts, and Social Sciences',
#        'College of Environmental Design', 'College of Science',
#        'College of Engineering', 'College of Hospitality Management',
#        'College of Education and Integrative Studies', 'Not Specified'],
#       dtype=object)

# %%
print(df[['Professor_Name', 'University', 'Department']].drop_duplicates().to_string(index=False))
# Out:
#                    Professor_Name                                    University                              Department
#                         Nancy Fan            College of Business Administration                   Accounting department
#                        Joonho Lee            College of Business Administration                   Accounting department
#                     Mohamed Gomaa            College of Business Administration                   Accounting department
#                           Mary Im            College of Business Administration                   Accounting department
#                   Leslie Sullivan            College of Business Administration                   Accounting department
#                   Gordon Anderson            College of Business Administration                   Accounting department
#                          Holly He            College of Business Administration                   Accounting department
#                       Ali Kowsari            College of Business Administration                   Accounting department
#                       Sharyn Fisk            College of Business Administration                   Accounting department
#                          Fei Kang            College of Business Administration                   Accounting department
#                          Nian Lee            College of Business Administration                   Accounting department
#                  Shinji Nishiyama            College of Business Administration                   Accounting department
#                          Hong Pak            College of Business Administration                   Accounting department
#                         Peter Hii            College of Business Administration                   Accounting department
#               Makalerina Tambunan            College of Business Administration                   Accounting department
#                       Rose Martin            College of Business Administration                   Accounting department
#                  Sepeedeh Ahadiat            College of Business Administration                   Accounting department
#                     William Foley            College of Business Administration                   Accounting department
#                      Hassan Hefzi            College of Business Administration                   Accounting department
#                      Verica Clark            College of Business Administration                   Accounting department
#                 Nasrollah Ahadiat            College of Business Administration                   Accounting department
#                       Magdy Farag            College of Business Administration                   Accounting department
#                       Robert Hurt            College of Business Administration                   Accounting department
#                        Alex Lemos            College of Business Administration                   Accounting department
#                        Meihua Koo            College of Business Administration                   Accounting department
#                      Yan-Shu Zhao            College of Business Administration                   Accounting department
#                     Rose Sheridan            College of Business Administration                   Accounting department
#                 Seepeedeh Ahadiat            College of Business Administration                   Accounting department
#                    Victor Cardona            College of Business Administration                   Accounting department
#                        Winnie Lim            College of Business Administration                   Accounting department
#                   Kathryn Johnson            College of Business Administration                   Accounting department
#                     Steven Flores            College of Business Administration                   Accounting department
#                        Shick Yoon            College of Business Administration                   Accounting department
#                    Hassan Damerji            College of Business Administration                   Accounting department
#                        Kirit Dave            College of Business Administration                   Accounting department
#                    Vincent Turner            College of Business Administration                   Accounting department
#               Christopher Gilbert            College of Business Administration                   Accounting department
#                      Anwar Salimi            College of Business Administration                   Accounting department
#                 Ahmed Abo-Hebeish            College of Business Administration                   Accounting department
#                      Vince Turner            College of Business Administration                   Accounting department
#                      Carroll King            College of Business Administration                   Accounting department
#                      John Plouffe            College of Business Administration                   Accounting department
#                       Nad Ahadiat            College of Business Administration                   Accounting department
#                     Andrea Watson                        College of Agriculture                  Agriculture department
#                      Naveen Hyder                        College of Agriculture                  Agriculture department
#                    Eeman At-Taras                        College of Agriculture                  Agriculture department
#                 Guadalupe Andrade                        College of Agriculture                  Agriculture department
#                      Bluebell cat                        College of Agriculture                  Agriculture department
#                     Joseph McHugh                        College of Agriculture                  Agriculture department
#                 Karoline Harrison                        College of Agriculture                  Agriculture department
#                    Nicole Hammack                        College of Agriculture                  Agriculture department
#                   Tracey Takeuchi                        College of Agriculture                  Agriculture department
#                     Elda Dervishi                        College of Agriculture                  Agriculture department
#                   Fatheema Subhan                        College of Agriculture                  Agriculture department
#                     Sophia Gaitan                        College of Agriculture                  Agriculture department
#                       Marcus Elam                        College of Agriculture                  Agriculture department
#                    Amber Freeland                        College of Agriculture                  Agriculture department
#                   Omolade Owoleke                        College of Agriculture                  Agriculture department
#                 AnnaLyce Brockham                        College of Agriculture                  Agriculture department
#                    Emily Kiresich                        College of Agriculture                  Agriculture department
#                  Kimberley Miller                        College of Agriculture                  Agriculture department
#                       Joanne Sohn                        College of Agriculture                  Agriculture department
#                     Miranda Aiken                        College of Agriculture                  Agriculture department
#                    Kathleen Earle                        College of Agriculture                  Agriculture department
#                     Katie Horvath                        College of Agriculture                  Agriculture department
#                      Dianne Trinh                        College of Agriculture                  Agriculture department
#                       Chelsi Dimm                        College of Agriculture                  Agriculture department
#                   Patricia Holley                        College of Agriculture                  Agriculture department
#                   Lucas Krusinski                        College of Agriculture                  Agriculture department
#                           Xu Yang                        College of Agriculture                  Agriculture department
#                       Lily Nguyen                        College of Agriculture                  Agriculture department
#                    Ondieki Gekara                        College of Agriculture                  Agriculture department
#                     Nancy Merlino                        College of Agriculture                  Agriculture department
#                    Dorothy Farias                        College of Agriculture                  Agriculture department
#                Eshwar Ravinshakar                        College of Agriculture                  Agriculture department
#                     Nicole Turner                        College of Agriculture                  Agriculture department
#                 Essam Abdelfattah                        College of Agriculture                  Agriculture department
#                      Tammy Peters                        College of Agriculture                  Agriculture department
#                    Javier Ramirez                        College of Agriculture                  Agriculture department
#                        Gina Crome                        College of Agriculture                  Agriculture department
#                       Erik Froyen                        College of Agriculture                  Agriculture department
#                    Maryam Tngrian                        College of Agriculture                  Agriculture department
#                Marguerite Mulhall                        College of Agriculture                  Agriculture department
#                         Alan Moss                        College of Agriculture                  Agriculture department
#                    Melody Wallace                        College of Agriculture                  Agriculture department
#                Donna Williamshill                        College of Agriculture                  Agriculture department
#                    Benjamin Lehan                        College of Agriculture                  Agriculture department
#                      Briana Smith                        College of Agriculture                  Agriculture department
#                     Rachel Flores                        College of Agriculture                  Agriculture department
#                    Elke Tetschner                        College of Agriculture                  Agriculture department
#                     Hyungchul Han                        College of Agriculture                  Agriculture department
#                    Nicole Hammock                        College of Agriculture                  Agriculture department
#                        Anna Soper                        College of Agriculture                  Agriculture department
#                     Jiangning Che                        College of Agriculture                  Agriculture department
#                            Yi Xie                        College of Agriculture                  Agriculture department
#                Steven Archambault                        College of Agriculture                  Agriculture department
#                       David Edens                        College of Agriculture                  Agriculture department
#                 Melissa McCormick                        College of Agriculture                  Agriculture department
#                         Aaron Fox                        College of Agriculture                  Agriculture department
#                   Shelton Murinda                        College of Agriculture                  Agriculture department
#                            Yao Li                        College of Agriculture                  Agriculture department
#                     Eileen Cullen                        College of Agriculture                  Agriculture department
#                    Margaret Earle                        College of Agriculture                  Agriculture department
#                Tory Simpfenderfer                        College of Agriculture                  Agriculture department
#                     Brianna Smith                        College of Agriculture                  Agriculture department
#                     Deborah Young                        College of Agriculture                  Agriculture department
#                  Koffajuah Toeque                        College of Agriculture                  Agriculture department
#                     Cord Brundage                        College of Agriculture                  Agriculture department
#                   Sean McLaughlin                        College of Agriculture                  Agriculture department
#                  Mohammad Chaichi                        College of Agriculture                  Agriculture department
#                     Asamoah Larbi                        College of Agriculture                  Agriculture department
#                  Michelle Buckley                        College of Agriculture                  Agriculture department
#                       Rose Olivas                        College of Agriculture                  Agriculture department
#                      Jon Phillips                        College of Agriculture                  Agriculture department
#                     Michelle Chon                        College of Agriculture                  Agriculture department
#                      Eunice Kahng                        College of Agriculture                  Agriculture department
#                      Edward Fonda                        College of Agriculture                  Agriculture department
#                      Priti Saxena                        College of Agriculture                  Agriculture department
#                     Andre Jackson                        College of Agriculture                  Agriculture department
#                     Beth Morrison                        College of Agriculture                  Agriculture department
#                Claire Southerland                        College of Agriculture                  Agriculture department
#                           Mon Yee                        College of Agriculture                  Agriculture department
#                      Lauren Meeks                        College of Agriculture                  Agriculture department
#                   Valerie Mellano                        College of Agriculture                  Agriculture department
#                      Amanda Marsh                        College of Agriculture                  Agriculture department
#                      Michele Rash                        College of Agriculture                  Agriculture department
#                       David Still                        College of Agriculture                  Agriculture department
#                      Duncan McKee                        College of Agriculture                  Agriculture department
#                      Ryan Nichols                        College of Agriculture                  Agriculture department
#                      Richard Kaae                        College of Agriculture                  Agriculture department
#                     Gavin Sherman                        College of Agriculture                  Agriculture department
#                    Victor Wegrzyn                        College of Agriculture                  Agriculture department
#                      Erica Pettey                        College of Agriculture                  Agriculture department
#                     Dan Hostetler                        College of Agriculture                  Agriculture department
#                        J Phillips                        College of Agriculture                  Agriculture department
#                    Shwu-Ying Jong                        College of Agriculture                  Agriculture department
#                       Peggy Perry                        College of Agriculture                  Agriculture department
#                    Frederick Roth                        College of Agriculture                  Agriculture department
#                  Victoria Bhavsar                        College of Agriculture                  Agriculture department
#                   Gregory Partida                        College of Agriculture                  Agriculture department
#                       Maria Omary                        College of Agriculture                  Agriculture department
#                      Rick Mathias                        College of Agriculture                  Agriculture department
#             Kara Caldwell-Freeman                        College of Agriculture                  Agriculture department
#                      Louis Foster                        College of Agriculture                  Agriculture department
#                       Mark Meskin                        College of Agriculture                  Agriculture department
#                     Douglas Lewis                        College of Agriculture                  Agriculture department
#                     Flint Freeman                        College of Agriculture                  Agriculture department
#                       Bill Hughes                        College of Agriculture                  Agriculture department
#                    Alexander Hess                        College of Agriculture                  Agriculture department
#                      Holly Greene                        College of Agriculture               Animal Science department
#                     Bruce Kennedy                        College of Agriculture               Animal Science department
#                         Mark Haag                        College of Agriculture               Animal Science department
#                    James Alderson                        College of Agriculture               Animal Science department
#                    Melissa Stiltz                        College of Agriculture               Animal Science department
#                    David Cheetham College of Letters, Arts, and Social Sciences                 Anthropology department
#                       Alexis Gray College of Letters, Arts, and Social Sciences                 Anthropology department
#                 Katherine Kinkopf College of Letters, Arts, and Social Sciences                 Anthropology department
#                     Teresa Delfin College of Letters, Arts, and Social Sciences                 Anthropology department
#                     Stephen James College of Letters, Arts, and Social Sciences                 Anthropology department
#                        Anne Danis College of Letters, Arts, and Social Sciences                 Anthropology department
#                    Sandra Vazquez College of Letters, Arts, and Social Sciences                 Anthropology department
#                      Patrick Polk College of Letters, Arts, and Social Sciences                 Anthropology department
#                  Claudia Lauriers College of Letters, Arts, and Social Sciences                 Anthropology department
#                    Craig Goralski College of Letters, Arts, and Social Sciences                 Anthropology department
#                       James Blair College of Letters, Arts, and Social Sciences                 Anthropology department
#                           Amy Dao College of Letters, Arts, and Social Sciences                 Anthropology department
#                    Maureen Hickey College of Letters, Arts, and Social Sciences                 Anthropology department
#                      Jill Wenrick College of Letters, Arts, and Social Sciences                 Anthropology department
#                       April Mejia College of Letters, Arts, and Social Sciences                 Anthropology department
#                      Maya Stovall College of Letters, Arts, and Social Sciences                 Anthropology department
#                      Lisa DeLance College of Letters, Arts, and Social Sciences                 Anthropology department
#                        Linda Hall College of Letters, Arts, and Social Sciences                 Anthropology department
#                       Thomas Fenn College of Letters, Arts, and Social Sciences                 Anthropology department
#                        Mark Allen College of Letters, Arts, and Social Sciences                 Anthropology department
#                        Ivana Mora College of Letters, Arts, and Social Sciences                 Anthropology department
#                   Matthew Whittle College of Letters, Arts, and Social Sciences                 Anthropology department
#                     Dorothy Wills College of Letters, Arts, and Social Sciences                 Anthropology department
#                Stephanie Meredith College of Letters, Arts, and Social Sciences                 Anthropology department
#                         Ann Acker College of Letters, Arts, and Social Sciences                 Anthropology department
#              Jessica Cerezo-Roman College of Letters, Arts, and Social Sciences                 Anthropology department
#                    Sharon Rachele College of Letters, Arts, and Social Sciences                 Anthropology department
#                        David Lord College of Letters, Arts, and Social Sciences                 Anthropology department
#                 Courtney Buchanan College of Letters, Arts, and Social Sciences                 Anthropology department
#                         Kelly Huh College of Letters, Arts, and Social Sciences                 Anthropology department
#                  Alejandra Parise                        College of Agriculture        Apparel Merchandising department
#                     Cindy Cordoba                        College of Agriculture        Apparel Merchandising department
#                           Su Shin                        College of Agriculture        Apparel Merchandising department
#                      Claire Whang                        College of Agriculture        Apparel Merchandising department
#                 Claudine Papillon                        College of Agriculture        Apparel Merchandising department
#                       Helen Trejo                        College of Agriculture        Apparel Merchandising department
#                       Yishuang Li                        College of Agriculture        Apparel Merchandising department
#                      Chitra Dabas                        College of Agriculture        Apparel Merchandising department
#                     Amanda Becker                        College of Agriculture        Apparel Merchandising department
#                        Saemee Lyu                        College of Agriculture        Apparel Merchandising department
#                        Nancy Hahn                        College of Agriculture        Apparel Merchandising department
#                       Ron Heimler                        College of Agriculture        Apparel Merchandising department
#                       Sheila Espy                        College of Agriculture        Apparel Merchandising department
#                   Deborah Johnson                        College of Agriculture        Apparel Merchandising department
#                      Linda Tucker                        College of Agriculture        Apparel Merchandising department
#                Muditha Senanayake                        College of Agriculture        Apparel Merchandising department
#                         Hynjoo Im                        College of Agriculture        Apparel Merchandising department
#                       Nadim Itani               College of Environmental Design                 Architecture department
#                        Jeehye Kim               College of Environmental Design                 Architecture department
#                      Douglas Kent               College of Environmental Design                 Architecture department
#                      Irma Ramirez               College of Environmental Design                 Architecture department
#                       Michael Fox               College of Environmental Design                 Architecture department
#                     Robert Clarke               College of Environmental Design                 Architecture department
#                Antonio Anfiteatro               College of Environmental Design                 Architecture department
#                     Sonia Brenner               College of Environmental Design                 Architecture department
#                    Behnam Samareh               College of Environmental Design                 Architecture department
#                     Alvaro Huerta               College of Environmental Design                 Architecture department
#                        Emma Price               College of Environmental Design                 Architecture department
#                 Roberto Sheinberg               College of Environmental Design                 Architecture department
#                         Alex Pang               College of Environmental Design                 Architecture department
#               Alexander Ortenberg               College of Environmental Design                 Architecture department
#                       Juintow Lin               College of Environmental Design                 Architecture department
#                     Pablo Laroche               College of Environmental Design                 Architecture department
#                    Richard Molina               College of Environmental Design                 Architecture department
#                   German Aparicio               College of Environmental Design                 Architecture department
#                  Giulia Amoresano               College of Environmental Design                 Architecture department
#                       Nick Hopson               College of Environmental Design                 Architecture department
#                       Annette Koh               College of Environmental Design                 Architecture department
#                  Ilaria Mazzoleni               College of Environmental Design                 Architecture department
#                    Claudia Wainer               College of Environmental Design                 Architecture department
#                      Apruva Pande               College of Environmental Design                 Architecture department
#                         Frank Wen               College of Environmental Design                 Architecture department
#                     Marc Schulitz               College of Environmental Design                 Architecture department
#                  Sasha plotnikova               College of Environmental Design                 Architecture department
#                    Sona Gevorkyan               College of Environmental Design                 Architecture department
#                    Garet Ammerman               College of Environmental Design                 Architecture department
#                  Katrin Terstegen               College of Environmental Design                 Architecture department
#                    George Proctor               College of Environmental Design                 Architecture department
#                     David Solomon               College of Environmental Design                 Architecture department
#                      Andrew Lords               College of Environmental Design                 Architecture department
#                  Mitchell Jarnett               College of Environmental Design                 Architecture department
#                       Ever Vargas               College of Environmental Design                 Architecture department
#                     Leslie Sydnor               College of Environmental Design                 Architecture department
#                  Robert Alexander               College of Environmental Design                 Architecture department
#                        Robyn Reed               College of Environmental Design                 Architecture department
#                    Andri Luescher               College of Environmental Design                 Architecture department
#                   Maria Sviridova               College of Environmental Design                 Architecture department
#                    Noam Saragosti               College of Environmental Design                 Architecture department
#                         John Bohn               College of Environmental Design                 Architecture department
#                        Sam Clovis               College of Environmental Design                 Architecture department
#                Giovanni Fruttaldo               College of Environmental Design                 Architecture department
#       Axel Prichard-Schmitzberger               College of Environmental Design                 Architecture department
#                    Sarah Lorenzen               College of Environmental Design                 Architecture department
#                   Michael Todoran               College of Environmental Design                 Architecture department
#                    Allyn Polancic               College of Environmental Design                 Architecture department
# Eric-Valentin Issertes-Carbonnier               College of Environmental Design                 Architecture department
#                       Kip Dickson               College of Environmental Design                 Architecture department
#                       Kyle Stover               College of Environmental Design                 Architecture department
#                      Lilian Pfaff               College of Environmental Design                 Architecture department
#                   Anton Schneider               College of Environmental Design                 Architecture department
#                           Hofu Wu               College of Environmental Design                 Architecture department
#                    Barry Milofsky               College of Environmental Design                 Architecture department
#                   Abhishek Tiwari               College of Environmental Design                 Architecture department
#                   Elizabeth Timme               College of Environmental Design                 Architecture department
#                  Lee-Anne Milburn               College of Environmental Design                 Architecture department
#                     Marissa Meeks               College of Environmental Design                 Architecture department
#                   Dennis McFadden               College of Environmental Design                 Architecture department
#                      Juan Salazar               College of Environmental Design                 Architecture department
#               Christopher Corbett               College of Environmental Design                 Architecture department
#                   Denise Lawrence               College of Environmental Design                 Architecture department
#                     Rachel Vassar               College of Environmental Design                 Architecture department
#                     Gerald Taylor               College of Environmental Design                 Architecture department
#                     Jose Herrasti               College of Environmental Design                 Architecture department
#                     Rebecca Lowry               College of Environmental Design                 Architecture department
#                     Ana Escalante               College of Environmental Design                 Architecture department
#                    Lance ODonnell               College of Environmental Design                 Architecture department
#                        Art Hacker               College of Environmental Design                 Architecture department
#                     Judith Sheine               College of Environmental Design                 Architecture department
#                  Juliann Wolfgram College of Letters, Arts, and Social Sciences                  Art History department
#                     Susan Croteau College of Letters, Arts, and Social Sciences                  Art History department
#                     Manuel Macias College of Letters, Arts, and Social Sciences                  Art History department
#                   Karlyn Griffith College of Letters, Arts, and Social Sciences                  Art History department
#                   Alison Pearlman College of Letters, Arts, and Social Sciences                  Art History department
#                      Diana Linden College of Letters, Arts, and Social Sciences                  Art History department
#                      Patrica Butz College of Letters, Arts, and Social Sciences                  Art History department
#                      Maria Pradel College of Letters, Arts, and Social Sciences                  Art History department
#                      Chari Pradel College of Letters, Arts, and Social Sciences                  Art History department
#                     Wendy Slatkin College of Letters, Arts, and Social Sciences                  Art History department
#                  Natasha Medvedev College of Letters, Arts, and Social Sciences                  Art History department
#                      John MacHado College of Letters, Arts, and Social Sciences                  Art History department
#                      Jamie Snyder                            College of Science                      Biology department
#                     Bharti Sharma                            College of Science                      Biology department
#                     Megan Hoppock                            College of Science                      Biology department
#                 Peter Arensburger                            College of Science                      Biology department
#                       Wendy Dixon                            College of Science                      Biology department
#                      Tatiane Lima                            College of Science                      Biology department
#                    Jasmine Michel                            College of Science                      Biology department
#                      Brenda Lango                            College of Science                      Biology department
#                    Joshua Paolini                            College of Science                      Biology department
#                    Glenn Kageyama                            College of Science                      Biology department
#           Andrea Bonisoli-Alquati                            College of Science                      Biology department
#             Christos Stathopoulos                            College of Science                      Biology department
#                    Paloma Zarazua                            College of Science                      Biology department
#                   Ashley Bartling                            College of Science                      Biology department
#                       Janel Ortiz                            College of Science                      Biology department
#                         Jason Lee                            College of Science                      Biology department
#                 Stephanie Rothman                            College of Science                      Biology department
#                       Dale McCabe                            College of Science                      Biology department
#                   Kevin Carpenter                            College of Science                      Biology department
#                      eliana Moisa                            College of Science                      Biology department
#                    Paul Beardsley                            College of Science                      Biology department
#                    Rachel Sanchez                            College of Science                      Biology department
#                       Marry Jones                            College of Science                      Biology department
#                     Monica Montes                            College of Science                      Biology department
#                    joshua herzler                            College of Science                      Biology department
#                        Steve Alas                            College of Science                      Biology department
#                     Andrew Steele                            College of Science                      Biology department
#                  Daniel Sebastian                            College of Science                      Biology department
#                    Yuanxiang Zhao                            College of Science                      Biology department
#                       Joseph Alas                            College of Science                      Biology department
#                 Brittney Crawford                            College of Science                      Biology department
#                      Craig Hoover                            College of Science                      Biology department
#                  Mackenzie Pekary                            College of Science                      Biology department
#                Elizabeth Scordato                            College of Science                      Biology department
#                  Danielle Garland                            College of Science                      Biology department
#            Rianna Hernandez-Thorn                            College of Science                      Biology department
#                   Samantha Sudoko                            College of Science                      Biology department
#                    Nathan Iverson                            College of Science                      Biology department
#                     Sal Gutierrez                            College of Science                      Biology department
#                         Rachel Le                            College of Science                      Biology department
#                    Francie Mercer                            College of Science                      Biology department
#                 Shourjya Majumder                            College of Science                      Biology department
#                     Destiny Rojas                            College of Science                      Biology department
#                     YuZhong Zhang                            College of Science                      Biology department
#                          Lucy Liu                            College of Science                      Biology department
#                   Nicole Reynolds                            College of Science                      Biology department
#                       Alyssa Bell                            College of Science                      Biology department
#                   George Mariscal                            College of Science                      Biology department
#                         Sy Truong                            College of Science                      Biology department
#                       Wei-Jen Lin                            College of Science                      Biology department
#               Alexandra Auslander                            College of Science                      Biology department
#                       Carla Stout                            College of Science                      Biology department
#                  Guadalupe Bernal                            College of Science                      Biology department
#                      Alvin Lappin                            College of Science                      Biology department
#                         Edward Jo                            College of Science                      Biology department
#                  Juanita Jellyman                            College of Science                      Biology department
#                   Douglas Durrant                            College of Science                      Biology department
#                      Cole Frazier                            College of Science                      Biology department
#                    Diana Castillo                            College of Science                      Biology department
#                       Tiffany Lim                            College of Science                      Biology department
#                       Frank Ewers                            College of Science                      Biology department
#                     Mathieu Leger                            College of Science                      Biology department
#                    Caleb Sandoval                            College of Science                      Biology department
#                       Jade Morris                            College of Science                      Biology department
#                   Cynthia Sanchez                            College of Science                      Biology department
#                        Mary Jones                            College of Science                      Biology department
#                        Zoe Walker                            College of Science                      Biology department
#                      Eric Breslau                            College of Science                      Biology department
#                     Rachel Blakey                            College of Science                      Biology department
#                     Sandra Banzon                            College of Science                      Biology department
#                     Lee Tharachai                            College of Science                      Biology department
#                 Nathanael Iverson                            College of Science                      Biology department
#                         Jason Ear                            College of Science                      Biology department
#              Angel Valdes-Gallego                            College of Science                      Biology department
#                         Sara Witt                            College of Science                      Biology department
#                  Sandra Dansereau                            College of Science                      Biology department
#                       Katrina Lam                            College of Science                      Biology department
#                          Jaime Ne                            College of Science                      Biology department
#                     Meghan Jeffus                            College of Science                      Biology department
#                       John Taylor                            College of Science                      Biology department
#                    Larissa Fields                            College of Science                      Biology department
#                  Michael Williams                            College of Science                      Biology department
#                        Jade Canal                            College of Science                      Biology department
#              Christian Pirijanian                            College of Science                      Biology department
#                    Audrey Johnson                            College of Science                      Biology department
#                    Adrianna Elihu                            College of Science                      Biology department
#                      Ayah Elsamad                            College of Science                      Biology department
#                        Joan Leong                            College of Science                      Biology department
#                    Taylor Edwards                            College of Science                      Biology department
#                    Anthony Powell                            College of Science                      Biology department
#                Christopher Waters                            College of Science                      Biology department
#                     Devin Lachner                            College of Science                      Biology department
#                     Edward Bobich                            College of Science                      Biology department
#                  Noah Szceszinski                            College of Science                      Biology department
#                    Brian Preciado                            College of Science                      Biology department
#                 Firozeh Farahmand                            College of Science                      Biology department
#                   Jennifer Flores                            College of Science                      Biology department
#                      Digisha Ahir                            College of Science                      Biology department
#                     Karina Moreno                            College of Science                      Biology department
#                     Robert Manuel                            College of Science                      Biology department
#                       Kevin Chung                            College of Science                      Biology department
#                     James Sturges                            College of Science                      Biology department
#                    Alexis Bloomer                            College of Science                      Biology department
#                         Justin Ho                            College of Science                      Biology department
#                    Jeremy Claisse                            College of Science                      Biology department
#                     Emma Trujillo                            College of Science                      Biology department
#                    Zecena Nereyda                            College of Science                      Biology department
#                     Suhani Bhakta                            College of Science                      Biology department
#                       Philip Butz                            College of Science                      Biology department
#                        Sean Agler                            College of Science                      Biology department
#                      John DiGildo                            College of Science                      Biology department
#                     Kristin Bozak                            College of Science                      Biology department
#                      Austin Pyles                            College of Science                      Biology department
#                   Kenneth Paredes                            College of Science                      Biology department
#                     Justin Medina                            College of Science                      Biology department
# ...
#                        Audra Harl                            College of Science                      Science department
#                      Keith Arnold                            College of Science                      Science department
#                      Peter Castro                            College of Science                      Science department
#                     Abdul Rashidi                            College of Science                      Science department
#                         Weian Liu                            College of Science                      Science department
#               Alejandro Rodriguez                            College of Science                      Science department
#                   Kevin Colangelo                            College of Science                      Science department
#                      Anthony Pena College of Letters, Arts, and Social Sciences               Social Science department
#                 Jacqueline Ashley College of Letters, Arts, and Social Sciences               Social Science department
#             Noemi Linares-Ramirez College of Letters, Arts, and Social Sciences               Social Science department
#                        Megan Wroe College of Letters, Arts, and Social Sciences               Social Science department
#                      Linda Mollno College of Letters, Arts, and Social Sciences               Social Science department
#                     Michael Times  College of Education and Integrative Studies                  Social Work department
#                    Amanda Newhall  College of Education and Integrative Studies                  Social Work department
#                       Jose Juarez  College of Education and Integrative Studies                  Social Work department
#                    Fernando Parra  College of Education and Integrative Studies                  Social Work department
#                    Jorge Camarena  College of Education and Integrative Studies                  Social Work department
#                    Anjana Narayan  College of Education and Integrative Studies                  Social Work department
#                 Cristine Chastain  College of Education and Integrative Studies                  Social Work department
#                         Steve Lin College of Letters, Arts, and Social Sciences                    Sociology department
#                    Anthony Ocampo College of Letters, Arts, and Social Sciences                    Sociology department
#                   Sekani Robinson College of Letters, Arts, and Social Sciences                    Sociology department
#               Deogratius Mshigeni College of Letters, Arts, and Social Sciences                    Sociology department
#                     Andrew Aleman College of Letters, Arts, and Social Sciences                    Sociology department
#                         Jack Fong College of Letters, Arts, and Social Sciences                    Sociology department
#                      Pablo Torres College of Letters, Arts, and Social Sciences                    Sociology department
#                   Philippe Duhart College of Letters, Arts, and Social Sciences                    Sociology department
#                 Alejandro Zermeno College of Letters, Arts, and Social Sciences                    Sociology department
#                      Peter Hanink College of Letters, Arts, and Social Sciences                    Sociology department
#                    Michael McKail College of Letters, Arts, and Social Sciences                    Sociology department
#                   Christian Lopez College of Letters, Arts, and Social Sciences                    Sociology department
#                     Carina Giorgi College of Letters, Arts, and Social Sciences                    Sociology department
#                        Faye Wachs College of Letters, Arts, and Social Sciences                    Sociology department
#                     Erica Morales College of Letters, Arts, and Social Sciences                    Sociology department
#                       Bianca Haro College of Letters, Arts, and Social Sciences                    Sociology department
#                           Min Yoo College of Letters, Arts, and Social Sciences                    Sociology department
#                   Jonathan Redman College of Letters, Arts, and Social Sciences                    Sociology department
#                   Joshua Cafferty College of Letters, Arts, and Social Sciences                    Sociology department
#                   Kathryn Daniels College of Letters, Arts, and Social Sciences                    Sociology department
#                 Gabriele Plickert College of Letters, Arts, and Social Sciences                    Sociology department
#                     Maria Anzaldo College of Letters, Arts, and Social Sciences                    Sociology department
#                      Julisa McCoy College of Letters, Arts, and Social Sciences                    Sociology department
#                     Edward Watson College of Letters, Arts, and Social Sciences                    Sociology department
#                     David Bogumil College of Letters, Arts, and Social Sciences                    Sociology department
#                      Jose Collazo College of Letters, Arts, and Social Sciences                    Sociology department
#                   Vanessa Delgado College of Letters, Arts, and Social Sciences                    Sociology department
#                          Cam Owen College of Letters, Arts, and Social Sciences                    Sociology department
#                    Steven Schmidt College of Letters, Arts, and Social Sciences                    Sociology department
#                        Helen Ross College of Letters, Arts, and Social Sciences                    Sociology department
#                       Julia McCoy College of Letters, Arts, and Social Sciences                    Sociology department
#                    Brianne Dávila College of Letters, Arts, and Social Sciences                    Sociology department
#                   Stephanie Jones College of Letters, Arts, and Social Sciences                    Sociology department
#                      Jessica Kang College of Letters, Arts, and Social Sciences                    Sociology department
#                       Mary Danico College of Letters, Arts, and Social Sciences                    Sociology department
#                       Sarah Muray College of Letters, Arts, and Social Sciences                    Sociology department
#                  Jessica Callahan College of Letters, Arts, and Social Sciences                    Sociology department
#                    Caitlin Clarke College of Letters, Arts, and Social Sciences                    Sociology department
#           Stela Krasteva-McCauley College of Letters, Arts, and Social Sciences                    Sociology department
#                        Dennis Loo College of Letters, Arts, and Social Sciences                    Sociology department
#                Gabrielle Plickert College of Letters, Arts, and Social Sciences                    Sociology department
#                      Gary Cretser College of Letters, Arts, and Social Sciences                    Sociology department
#                     John McCollum College of Letters, Arts, and Social Sciences                    Sociology department
#                   Laura Zlotowski College of Letters, Arts, and Social Sciences                    Sociology department
#                     Mikayla Smith College of Letters, Arts, and Social Sciences                    Sociology department
#                  Stacy McGoldrick College of Letters, Arts, and Social Sciences                    Sociology department
#                   Kevin McCaffree College of Letters, Arts, and Social Sciences                    Sociology department
#                       Paul Morgan College of Letters, Arts, and Social Sciences                    Sociology department
#                     Jessica Kizer College of Letters, Arts, and Social Sciences                    Sociology department
#                        Janet Hill College of Letters, Arts, and Social Sciences                    Sociology department
#                  Jane Ollenburger College of Letters, Arts, and Social Sciences                    Sociology department
#                      Wayne Wooden College of Letters, Arts, and Social Sciences                    Sociology department
#                         Wenge Zhu            College of Business Administration   Technology Operations Mgmt department
#             Namakkal Balakrishnan            College of Business Administration   Technology Operations Mgmt department
#                        Yuanjie He            College of Business Administration   Technology Operations Mgmt department
#                 Halati Abolhassan            College of Business Administration   Technology Operations Mgmt department
#                    Kazem Darbandi            College of Business Administration   Technology Operations Mgmt department
#                    Abdelati Krimi            College of Business Administration   Technology Operations Mgmt department
#                         John Knox            College of Business Administration   Technology Operations Mgmt department
#                     Charles White College of Letters, Arts, and Social Sciences                      Theater department
#                      John Sylvain College of Letters, Arts, and Social Sciences                      Theater department
#                    Laura Epperson College of Letters, Arts, and Social Sciences                      Theater department
#                      Jake Wachtel College of Letters, Arts, and Social Sciences                      Theater department
#                     Thomas Bryant College of Letters, Arts, and Social Sciences                      Theater department
#                Zachary Groenewold College of Letters, Arts, and Social Sciences                      Theater department
#                 Michael Kachingwe College of Letters, Arts, and Social Sciences                      Theater department
#                      Brian Newman College of Letters, Arts, and Social Sciences                      Theater department
#                     Marissa Pitts College of Letters, Arts, and Social Sciences                      Theater department
#                      Paula Solano College of Letters, Arts, and Social Sciences                      Theater department
#                       Jill Holden College of Letters, Arts, and Social Sciences                      Theater department
#                     Richard Pluim College of Letters, Arts, and Social Sciences                      Theater department
#                      Sarah Kranin College of Letters, Arts, and Social Sciences                      Theater department
#                        Paulo Lima College of Letters, Arts, and Social Sciences                      Theater department
#                    Rainy Demerson College of Letters, Arts, and Social Sciences                      Theater department
#                      Gayle Fekete College of Letters, Arts, and Social Sciences                      Theater department
#                    Roberto Oregel College of Letters, Arts, and Social Sciences                      Theater department
#                    Emma Mesrobian College of Letters, Arts, and Social Sciences                      Theater department
#                      Louis Fossum College of Letters, Arts, and Social Sciences                      Theater department
#                      Bruce Warner College of Letters, Arts, and Social Sciences                      Theater department
#                 Jeffery Eisenmann College of Letters, Arts, and Social Sciences                      Theater department
#                   Lisa Brownfield               College of Environmental Design      Urban Regional Planning department
#                            Do Kim               College of Environmental Design      Urban Regional Planning department
#                    Annalise Fonza               College of Environmental Design      Urban Regional Planning department
#                     Scott Reimers               College of Environmental Design      Urban Regional Planning department
#                        So-Ra Baek               College of Environmental Design      Urban Regional Planning department
#                        Dina Karim               College of Environmental Design      Urban Regional Planning department
#                    Nicole Lambrou               College of Environmental Design      Urban Regional Planning department
#                  Shawnika Johnson               College of Environmental Design      Urban Regional Planning department
#                    Abishek Tiwari               College of Environmental Design      Urban Regional Planning department
#                   Steven Sandifer               College of Environmental Design      Urban Regional Planning department
#             Christopher Giamarino               College of Environmental Design      Urban Regional Planning department
#                   Joseph Catalano               College of Environmental Design      Urban Regional Planning department
#              Brandy Chappell-Hill               College of Environmental Design      Urban Regional Planning department
#               Fernanda Jahn-Verri               College of Environmental Design      Urban Regional Planning department
#                    Jerry Mitchell               College of Environmental Design      Urban Regional Planning department
#                      Brian Garcia               College of Environmental Design      Urban Regional Planning department
#                         Yonsu Kim               College of Environmental Design      Urban Regional Planning department
#                          Ata Khan               College of Environmental Design      Urban Regional Planning department
#                    Steven Preston               College of Environmental Design      Urban Regional Planning department
#                   Juliana Delgado               College of Environmental Design                 Urban Design department
#                    Richard Zimmer               College of Environmental Design                 Urban Design department
#                            Kim Do               College of Environmental Design                 Urban Design department
#                         Gwen Urey               College of Environmental Design                 Urban Design department
#                     Daniel Yuhasz               College of Environmental Design                 Urban Design department
#                     Felix Barreto               College of Environmental Design                 Urban Design department
#                      Ana Whitaker               College of Environmental Design                 Urban Design department
#                       Wei Bidlack                        College of Agriculture          Veterinary Sciences department
#                      Sandra Dixon College of Letters, Arts, and Social Sciences               Gender Studies department
#                    Nancy Quiñones College of Letters, Arts, and Social Sciences               Gender Studies department
#                      Patricia Lin College of Letters, Arts, and Social Sciences               Gender Studies department
#                     Jaehoon Seong                            College of Science                      Science department
#             Barbara Harmer-Garcia                            College of Science                  Physical Ed department
#                     Rhodes Rhonda                                 Not Specified                Not Specified department
#                        Angie Song                                 Not Specified                Not Specified department

# %%
df[['Professor_Name', 'University']].drop_duplicates().groupby(['University']).count()
# Out:
#                                                Professor_Name
# University
# College of Agriculture                                    134
# College of Business Administration                        312
# College of Education and Integrative Studies               73
# College of Engineering                                    343
# College of Environmental Design                           151
# College of Hospitality Management                          44
# College of Letters, Arts, and Social Sciences             740
# College of Science                                        731
# Not Specified                                               2

# %%
df = df.rename(columns={'University': 'Colleges'})

# %%
df
# Out:
#        Professor_ID Professor_Name                            Colleges  \
# 0           1277216      Nancy Fan  College of Business Administration
# 1           1277216      Nancy Fan  College of Business Administration
# 2           1277216      Nancy Fan  College of Business Administration
# 3           1277216      Nancy Fan  College of Business Administration
# 4           1277216      Nancy Fan  College of Business Administration
# ...             ...            ...                                 ...
# 34640        958068  Rhodes Rhonda                       Not Specified
# 34641        958068  Rhodes Rhonda                       Not Specified
# 34642        959066     Angie Song                       Not Specified
# 34643        959066     Angie Song                       Not Specified
# 34645        959066     Angie Song                       Not Specified
#
#                      Department  Quality  Difficulty Class_Name  \
# 0         Accounting department        1           5    ACC3120
# 1         Accounting department        1           3    ACC3120
# 2         Accounting department        1           4    ACC3120
# 3         Accounting department        1           4    ACC3110
# 4         Accounting department        2           4    ACC3120
# ...                         ...      ...         ...        ...
# 34640  Not Specified department        4           3     EBZ466
# 34641  Not Specified department        4           2     TOM411
# 34642  Not Specified department        4           2      LA251
# 34643  Not Specified department        5           2    CADSECT
# 34645  Not Specified department        4           2      LA252
#
#                                                  Comment  Thumbs_Up  \
# 0      Nancy Fan holds the keys to your future. Cal P...          0
# 1      She jumps over read the textbook. Shows you th...          0
# 2      Unfortunately, she's the only one teaching ACC...          1
# 3                   PLEASE DO NOT TAKE HER!!!!!!!!!!!!!!          0
# 4      Her homework is done through McGraw Hill. Alth...          0
# ...                                                  ...        ...
# 34640  You get a choice to do either an internship or...          0
# 34641  Class is easy. The only hard part would probab...          0
# 34642  She is very helpful, very clear in her critics...          0
# 34643                                        No Comments          0
# 34645  Very helpful teacher no matter how little you ...          0
#
#        Thumbs_Down     Review_Date
# 0                0  Mar 19th, 2025
# 1                0  Mar 13th, 2025
# 2                0  Feb 11th, 2025
# 3                0   Feb 6th, 2025
# 4                0   Feb 5th, 2025
# ...            ...             ...
# 34640            0  Dec 16th, 2009
# 34641            0   Aug 6th, 2009
# 34642            0  Dec 17th, 2009
# 34643            0  Jul 31st, 2007
# 34645            0  Feb 16th, 2007
#
# [34607 rows x 11 columns]

# %%
df['Quality'].unique()
# Out:
# array([1, 2, 3, 5, 4])

# %%
df['Difficulty'].unique()
# Out:
# array([5, 3, 4, 2, 1])

# %%
df['Class_Name'].unique()
# Out:
# array(['ACC3120', 'ACC3110', 'ACC207', ..., 'LA251', 'CADSECT', 'LA252'],
#       dtype=object)

# %%
df['Class_Name'].value_counts()
# Out:
# Class_Name
# PLS2010    410
# ENG1103    401
# COM1100    386
# MAT1150    310
# MAT2140    277
#           ...
# HIST364      1
# HST342       1
# HST3343      1
# CS5550       1
# LA252        1
# Name: count, Length: 4557, dtype: int64

# %%
df['Class_Name'] = df['Class_Name'].str.replace(r'[^a-zA-Z0-9]', '', regex=True)

# %%
print(df['Class_Name'].unique().tolist())
# Out:
# ['ACC3120', 'ACC3110', 'ACC207', 'ACC311', 'ACCT3120', 'ACC313', 'ACC312', 'ACC2070', 'ACCT3110', 'ACCT312', 'ACC2080', 'ACCT4510', 'ACC4530', 'ACC4510', 'ACC4821', 'ACC4990', 'ACC208', 'ACC4711', 'ACC6701600', 'ACC3210', 'ACC304', 'ABM2010', 'ABM3090', 'ABM2240', 'IBM3001', 'BUS3102', 'ACC4310', 'ACC431', 'ACC432', 'ACC4810', 'ACC307', 'A4510', 'ACCTG3110', 'ACC4403', 'ACC4811', 'ACC4831', 'ACCT202', 'GBA6080', 'ACC4221', 'AIS4510', 'ACC305', 'ACC3045', 'ACCOUNTING', 'ACCTG454', 'ACCT208', 'ACTG208', 'ETC279', 'ACC419', 'ACC418', 'ACCT304', 'ACCTG1A', 'ACCTG1', 'ACC6400', 'ACC4341S', 'ACC4411', 'ACC207A', 'ACC208A', 'ACCT207', 'ACCT210', 'ACC207208', '207', 'ACC4401', 'ACC4841', 'CIS3100', 'GBA608', 'FRL300', 'STAX434', '35348', 'ACCT1A', 'ACC', 'CISB7', 'ACCT401', 'ACCT311', 'ACCT307', 'AVS3350L', 'AVS1112', 'AVS1113', '1114L', 'AVS3050', 'AVS113', 'AG4010', 'PLT2140', 'PLT4280', 'PLT4010', 'PLT4311', 'PLT214', 'AG406', 'AG401', 'AGETHICS400', 'PLT311', 'AG101', 'AVS3350', 'AVS4214', 'AVS3456', 'AVS1114L', '2420', 'MEOW101', 'CPP', 'AVS4430L', 'FST3250', 'FST2250', 'FST3210', 'FST325', 'AG1110', 'AG1010', 'PLT1120', 'PLT3310', 'PLT132', 'NTR2180', 'NTR3280', 'EWS2180', 'NTREWS2180', 'NTR3450', '1114', 'NTR2350L', 'NTR3930', 'FN435', 'NTR2350', 'NTR3350', 'F434', 'FN235', 'AVS1000', 'AVS3311', '3235L', '2208', 'NTR4460', 'AVS112', 'AGS420', 'AHS3263', 'AHS1104', 'PLT2310', 'AVS3333', 'AVS1113L', 'AVS2990', 'AVS1115L', 'AVS1070', 'AVS350', 'AVS101', 'AVS350L', '2010ABM', 'ABM4020', 'ABM4500', 'ABM4420', 'AG111', 'ABM3130', 'ABM3040', 'FST1250', 'FST125', 'FST321', 'AG2050', 'AG2010', 'EWS2050', 'AVS3305', 'FST1000', 'AVS115L', 'AVS2101', 'AVS2101L', 'AVS4402', 'AVS402', 'AVS114', 'AG100', 'PSY4010', 'ABM464', 'AG402', 'ABM402', 'ABM4640', 'ABM309', 'ABM', 'ABMALL', 'FMA299', 'FMAALL', 'FMA304', 'WATERMGMT', 'ABM304', 'ABM3300', 'PLT1120L', 'AVS1114', '2101L', 'AVS2102L', 'AVS1115', 'AVS114L', 'NTR3050', 'NTR2050', 'NTR2030', 'FN235L', 'FN100', 'FN335', 'NTR3130', 'NTR3940', 'AVS3327', 'AVS327', 'ABM3260', 'ABM2260', 'PLT2320', 'PLT1000', '3305L', 'AHS3305', 'AHS302', 'PLT3000', 'PLT3030', 'PLT3630', 'AG5100', '3030PLT', 'PLT2330', 'PLT233', 'PLT300', 'FN202', 'FN263', 'AMM3100', 'AMM301', 'AMM360', 'AMM2600', 'AMM160', 'AMM1600', 'ABM3110', 'ABM3750', 'NTR3670', 'NTR1210L', '1210L', 'FN121L', 'AHS2202', 'AHS1129', 'PLT3650', 'AVS4430', 'AVS4411', 'AVS463', 'FST4170', 'FST3321', 'PLT3760', 'PLT333', 'PLT411', 'PLT401', '233', 'TEX2600', 'AMM260', 'AMM1010', 'BIO312', 'BIO312LAB', 'AVS4610', 'AVS412', 'PLT2990', 'PLT2400', 'PLT2400L', 'PLT2230', 'AG202', 'IA101', 'AGR101', 'ABM2010S', 'AVS1112L', 'AVS414', 'AVS311', 'AVS112114', 'AVS112114L', 'SWINEMANAGMENT', 'AVS414412', 'PLT1130', 'PLT301', 'AG2480', 'RS3030', 'PLT231', 'FN203', 'PSY433', 'PSY455', 'ABM450', 'AVS115', 'AHS110', 'AHS210', 'AHS129', 'AHS128', 'AHS113', 'HORT100', 'AHS', 'AVS128', 'AHS128L', 'PLANTBREEDING', 'PLANTBREE', 'AGR404', '132', 'PLT133', 'AGB300', 'PLT336', 'PLT302', 'AGB336', 'AGRNA', 'AGS112', 'AGR300', 'AGR401', 'AGR437', 'SUSTAINABLEAG', 'PLT220', 'PLT223', 'ABM224', '3', 'PLT328', 'NTRS410', 'FST121', 'FMA224', 'FMA324', 'FMA324375306', 'FS100', 'AVS333', 'AVHSALL', 'FN433', 'AG400', 'AGS300', 'SHEEPMGMT', 'AVS123', 'AG', 'FMA100', 'FMA', 'EQUINESCIENCE', 'AGS440', 'AVS2434', 'AVS1125', 'AHS3369L', 'AHS369', 'AVS211', 'AHS202', 'AVS201', 'AHS202L', 'ANT3500', 'ANT102', 'ANT3600', 'ANT360', 'ANT1020', 'ANT350', 'ANT101', 'ANT201', 'ANT1010', 'ANT1120', 'ANT4910', 'ANT112', 'ANT2010', 'ANT491', 'ANTH4910', 'ANTH102', 'ANTH112', 'ANT2', 'ANTH2', 'CULTANTHR', 'ANT1010H', 'ANT1040', 'ANTH3600', 'ANT3520', 'ANT1020H', 'ANTHRO3600', 'ANT2580', 'ANT3530', 'ANT3790', 'ANT4300', 'IGE3300', 'IGE3600', 'CPU2990H', 'ANTAST3050H', 'ANT1030', 'ANT330', 'ANT103', 'ANTH360', 'ANT3500HS', 'ANT4800', 'PHL2010', 'ANT3400', 'ANT340', 'ANTHRO350', 'LS4211', 'LS4611', 'LS3021', 'LS3031', 'ANTH1010', 'ANTH1413', 'ANT1026', 'ANT3220', 'ANT322', 'ANT460', 'ANT380', 'ANTHRO ...

# %%
df['Thumbs_Up'].unique()
# Out:
# array([ 0,  1,  2,  3,  5,  4,  9, 10,  7,  8,  6, 15, 11, 12, 17, 14, 13,
#        -1, 42, 50, 27, 19, 18, 16, 57, 21, 33, 36, 40, 34, 37, 35, 32, 25,
#        20, 73, 76, 85, 86, 46, 44, 49, 38, 23, 39, 53, 43])

# %%
df[df['Thumbs_Up'] == -1]
# Out:
#       Professor_ID  Professor_Name            Colleges            Department  \
# 6896        660952  Laurie Starkey  College of Science  Chemistry department
#
#       Quality  Difficulty     Class_Name  \
# 6896        1           5  CHM315ORGANIC
#
#                                                 Comment  Thumbs_Up  \
# 6896  She expects you to watch lecture videos prior ...         -1
#
#       Thumbs_Down     Review_Date
# 6896            1  May 16th, 2022

# %%
df.loc[6896, 'Thumbs_Up'] = 0

# %%
df.loc[6896, 'Thumbs_Up']
# Out:
# 0

# %%
df['Thumbs_Down'].unique()
# Out:
# array([ 0,  3,  2,  4,  1,  5,  7,  8, 11,  6,  9, 12, 18, 13, 10, 14, 15,
#        16, 24, 66, 38, 49, 22, 37, 21, 19, 26, 29, 25, 36, 43, 30, 27, 20,
#        44, 17, 39, 34])

# %%
df['Review_Date'].unique()
# Out:
# array(['Mar 19th, 2025', 'Mar 13th, 2025', 'Feb 11th, 2025', ...,
#        'Mar 22nd, 2006', 'Dec 26th, 2009', 'Sep 7th, 2017'], dtype=object)

# %%
# Step 1: Remove day suffixes
suffixes = ['st', 'nd', 'rd', 'th']
for suffix in suffixes:
    df['Review_Date'] = df['Review_Date'].str.replace(suffix, '', case=False)

# Step 2: Convert to datetime
df['Review_Date'] = pd.to_datetime(df['Review_Date'], format='%b %d, %Y')

# %%
df
# Out:
#        Professor_ID Professor_Name                            Colleges  \
# 0           1277216      Nancy Fan  College of Business Administration
# 1           1277216      Nancy Fan  College of Business Administration
# 2           1277216      Nancy Fan  College of Business Administration
# 3           1277216      Nancy Fan  College of Business Administration
# 4           1277216      Nancy Fan  College of Business Administration
# ...             ...            ...                                 ...
# 34640        958068  Rhodes Rhonda                       Not Specified
# 34641        958068  Rhodes Rhonda                       Not Specified
# 34642        959066     Angie Song                       Not Specified
# 34643        959066     Angie Song                       Not Specified
# 34645        959066     Angie Song                       Not Specified
#
#                      Department  Quality  Difficulty Class_Name  \
# 0         Accounting department        1           5    ACC3120
# 1         Accounting department        1           3    ACC3120
# 2         Accounting department        1           4    ACC3120
# 3         Accounting department        1           4    ACC3110
# 4         Accounting department        2           4    ACC3120
# ...                         ...      ...         ...        ...
# 34640  Not Specified department        4           3     EBZ466
# 34641  Not Specified department        4           2     TOM411
# 34642  Not Specified department        4           2      LA251
# 34643  Not Specified department        5           2    CADSECT
# 34645  Not Specified department        4           2      LA252
#
#                                                  Comment  Thumbs_Up  \
# 0      Nancy Fan holds the keys to your future. Cal P...          0
# 1      She jumps over read the textbook. Shows you th...          0
# 2      Unfortunately, she's the only one teaching ACC...          1
# 3                   PLEASE DO NOT TAKE HER!!!!!!!!!!!!!!          0
# 4      Her homework is done through McGraw Hill. Alth...          0
# ...                                                  ...        ...
# 34640  You get a choice to do either an internship or...          0
# 34641  Class is easy. The only hard part would probab...          0
# 34642  She is very helpful, very clear in her critics...          0
# 34643                                        No Comments          0
# 34645  Very helpful teacher no matter how little you ...          0
#
#        Thumbs_Down Review_Date
# 0                0  2025-03-19
# 1                0  2025-03-13
# 2                0  2025-02-11
# 3                0  2025-02-06
# 4                0  2025-02-05
# ...            ...         ...
# 34640            0  2009-12-16
# 34641            0  2009-08-06
# 34642            0  2009-12-17
# 34643            0  2007-07-31
# 34645            0  2007-02-16
#
# [34607 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34607 entries, 0 to 34645
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Professor_ID    34607 non-null  int64
#  1   Professor_Name  34607 non-null  object
#  2   Colleges        34607 non-null  object
#  3   Department      34607 non-null  object
#  4   Quality         34607 non-null  int32
#  5   Difficulty      34607 non-null  int32
#  6   Class_Name      34607 non-null  object
#  7   Comment         34607 non-null  object
#  8   Thumbs_Up       34607 non-null  int32
#  9   Thumbs_Down     34607 non-null  int32
#  10  Review_Date     34607 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int32(4), int64(1), object(5)
# memory usage: 3.6+ MB

# %% [markdown]
# # Finalization of Cleaned DataFrame
# To prepare the dataset for analysis, we performed several key final cleaning steps to ensure consistency, accuracy, and usability:
#
#     Standardization of Professor Names: We carefully standardized the formatting of professor names, ensuring uniform casing and spacing. When middle names or initials were present, we retained only the first and last names to avoid inconsistencies. Care was taken to avoid unintentionally merging or removing distinct entries that differed only by middle names or initials.
#
#     Conversion of 'Would_Take_Again' to Float: The 'Would_Take_Again' column, originally containing percentage values as strings (e.g., "75%") or missing entries, was cleaned by stripping the percentage sign, converting to float (e.g., 75.0), and filling missing values with 0.0 for consistency and numeric analysis.
#
#     Duplicate Checking: We checked for and removed any exact duplicate rows that could distort the analysis. Additionally, near-duplicates based on key features (e.g., professor name and course) were reviewed and verified to ensure no data was mistakenly discarded.
#
#     Validation of Numerical Columns: We conducted sanity checks on numeric columns like 'avg_rating', 'avg_difficulty', and 'Would_Take_Again' to ensure no out-of-range or unusual values existed. These columns were confirmed to fall within expected boundaries (e.g., ratings between 1 and 5, difficulties between 1 and 5, and percentages between 0 and 100).
#
#     Department Name Standardization: We standardized department names to eliminate variations due to abbreviations, typos, or inconsistent naming (e.g., "Comp Sci", "Computer Science Dept" → "Computer Science"). This step ensures that aggregation and grouping by department remain accurate.

# %%
# Saving the Cleaned Dataframe
df.to_csv('clean_reviews.csv',index=False)

# %% [markdown]
# However, given that we are joining these two csv in SQL. I believe it would be best to also have another csv sheet dropping the Professor_Name and Department Column in order to save memory and increase processing times.

# %%
df.drop(['Professor_Name', 'Department'], axis=1, inplace=True)

# %%
df
# Out:
#        Professor_ID                            Colleges  Quality  Difficulty  \
# 0           1277216  College of Business Administration        1           5
# 1           1277216  College of Business Administration        1           3
# 2           1277216  College of Business Administration        1           4
# 3           1277216  College of Business Administration        1           4
# 4           1277216  College of Business Administration        2           4
# ...             ...                                 ...      ...         ...
# 34640        958068                       Not Specified        4           3
# 34641        958068                       Not Specified        4           2
# 34642        959066                       Not Specified        4           2
# 34643        959066                       Not Specified        5           2
# 34645        959066                       Not Specified        4           2
#
#       Class_Name                                            Comment  \
# 0        ACC3120  Nancy Fan holds the keys to your future. Cal P...
# 1        ACC3120  She jumps over read the textbook. Shows you th...
# 2        ACC3120  Unfortunately, she's the only one teaching ACC...
# 3        ACC3110               PLEASE DO NOT TAKE HER!!!!!!!!!!!!!!
# 4        ACC3120  Her homework is done through McGraw Hill. Alth...
# ...          ...                                                ...
# 34640     EBZ466  You get a choice to do either an internship or...
# 34641     TOM411  Class is easy. The only hard part would probab...
# 34642      LA251  She is very helpful, very clear in her critics...
# 34643    CADSECT                                        No Comments
# 34645      LA252  Very helpful teacher no matter how little you ...
#
#        Thumbs_Up  Thumbs_Down Review_Date
# 0              0            0  2025-03-19
# 1              0            0  2025-03-13
# 2              1            0  2025-02-11
# 3              0            0  2025-02-06
# 4              0            0  2025-02-05
# ...          ...          ...         ...
# 34640          0            0  2009-12-16
# 34641          0            0  2009-08-06
# 34642          0            0  2009-12-17
# 34643          0            0  2007-07-31
# 34645          0            0  2007-02-16
#
# [34607 rows x 9 columns]

# %%
df.to_csv('clean_reviews_noname_nodepart.csv',index=False)
